# %%
# !pip install git+https://github.com/Artvr1t0/test-lib.git
# Out:
# ...
#   Cloning https://github.com/Artvr1t0/test-lib.git to c:\users\usuario\appdata\local\temp\pip-req-build-5wou0qcc
#   Resolved https://github.com/Artvr1t0/test-lib.git to commit 07cf8dbe1a5412e63c19f9e3dac400a064fc1b53
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   Running command git clone --filter=blob:none --quiet https://github.com/Artvr1t0/test-lib.git 'C:\Users\Usuario\AppData\Local\Temp\pip-req-build-5wou0qcc'
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [96 lines of output]
#       configuration error: `project.license` must be valid exactly by one definition (2 matches found):
#
#           - keys:
#               'file': {type: string}
#             required: ['file']
#           - keys:
# ...
